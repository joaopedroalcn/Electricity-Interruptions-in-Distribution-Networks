# %% [markdown]
# # "Pré-processamento de Dados para Mineração: Uma Abordagem Prática com a Base de Dados: Interrupções de Energia Elétrica nas Redes de Distribuição"
#
# <h2>Introdução</h2>
#
# Na mineração de dados, o pré-processamento é o ponto de partida essencial para garantir a qualidade e a utilidade dos dados que serão analisados. É o processo de limpeza, organização e preparação dos dados brutos para análise posterior. Sem um pré-processamento adequado, os dados podem conter ruído, inconsistências e valores ausentes, o que pode levar a conclusões errôneas e modelos imprecisos. Portanto, entender a importância do pré-processamento de dados é fundamental para garantir resultados confiáveis e significativos na mineração de dados. Nesta introdução, exploraremos brevemente o papel crucial do pré-processamento na extração de informações valiosas a partir de conjuntos de dados.
#
# <h2>Objetivo</h2>
#
# O objetivo deste trabalho é aplicar técnicas de pré-processamento em uma base de dados específica, com foco na preparação dos dados para análises futuras relacionadas ao tema "Interrupções de Energia Elétrica nas Redes de Distribuição". Essas técnicas visam limpar, organizar e transformar os dados brutos em um formato mais adequado e compreensível, de modo a facilitar a extração de informações relevantes sobre interrupções de energia elétrica. Ao realizar o pré-processamento, buscamos identificar e corrigir inconsistências, preencher valores ausentes, remover outliers e transformar os dados conforme necessário para facilitar análises estatísticas, modelagem preditiva ou qualquer outra forma de análise exploratória. O objetivo final é preparar a base de dados de forma que possa fornecer insights significativos e precisos sobre os padrões, causas e impactos das interrupções de energia elétrica nas redes de distribuição, contribuindo assim para melhorias na gestão e manutenção dessas redes.
#
# <h2>Descrição da Base de Dados</h2>
#
# A base de dados escolhida é uma coleção abrangente de informações sobre todas as interrupções de energia elétrica ocorridas nas redes de distribuição de energia elétrica do Brasil. Aqui está uma descrição detalhada:
#
# **Fonte dos Dados**: Os dados são coletados de várias redes de distribuição de energia elétrica em todo o país. No entanto, é importante notar que as interrupções ocorridas em áreas sob gestão de permissionárias de serviço público (cooperativas) regulamentados pela ANEEL não estão incluídas nesta base de dados.
#
# **Natureza dos Dados**: Os dados são de natureza quantitativa e temporal, registrando cada interrupção de energia elétrica em termos de sua duração, localização, causa e outros detalhes relevantes. Eles são estruturados e organizados de maneira a facilitar análises e relatórios detalhados.
#
# **Relevância dos Dados**: Esta base de dados é extremamente relevante para uma variedade de aplicações. Ela pode ser usada para analisar a confiabilidade das redes de distribuição de energia, identificar áreas problemáticas que precisam de manutenção ou atualização, e desenvolver estratégias para minimizar interrupções futuras. Além disso, os dados podem ser úteis para pesquisadores que estudam a infraestrutura de energia do país, bem como para formuladores de políticas que buscam melhorar a resiliência e eficiência do sistema de energia.
#
# Em resumo, esta base de dados oferece uma visão valiosa sobre o desempenho das redes de distribuição de energia elétrica do Brasil, contribuindo para esforços contínuos de melhoria e inovação no setor de energia.
#
# <h2>Trabalhos Relacionados</h2>
#
# Existem trabalhos na literatura que utilizaram a base de dados de interrupções de energia elétrica. Aqui estão alguns exemplos:
#
# Barros, André. Análise das principais causas de descontinuidade no fornecimento de energia elétrica e de seus impactos nos indicadores de qualidade. Ano 2024. Número de páginas 200. Monografia (Graduação em Engenharia Elétrica) - Escola Politécnica, Universidade Federal do Rio de Janeiro, Cidade, Ano. Disponível em: http://www.repositorio.poli.ufrj.br/monografias/monopoli10032029.pdf. Acesso em: 29/05/2024.
#
#
# INTERUPÇÕES de energia elétrica registram queda no Brasil em 2020, diz ANEEL. Correio Braziliense, Brasília, 25 mar. 2021. Economia. Disponível em: https://www.correiobraziliense.com.br/economia/2021/03/4912026-interrupcoes-de-energia-eletrica-registram-queda-no-brasil-em-2020-diz-aneel.html. Acesso em: 29 maio 2024.
#
#
# <h2>Metodologia</h2>
#
# A base de dados “Interrupções de Energia Elétrica nas Redes de Distribuição” é uma escolha pelas razões:
#
# **Relevância**: Esta base de dados é extremamente relevante para entender a performance e confiabilidade das redes de distribuição de energia elétrica do Brasil. Ela pode ajudar a identificar áreas problemáticas e desenvolver estratégias para minimizar interrupções futuras.
#
# **Compreensividade**: A base de dados oferece uma visão abrangente das interrupções de energia, incluindo detalhes como duração, localização e causa. Isso permite uma análise detalhada e aprofundada.
#
# **Aplicabilidade**: Os dados podem ser usados em uma variedade de aplicações, desde a melhoria da infraestrutura de energia até a formulação de políticas públicas. Além disso, eles são úteis para pesquisadores que estudam a infraestrutura de energia do país.
#
# **Atualidade**: Como os dados são coletados continuamente, eles fornecem uma visão atual e em tempo real das interrupções de energia, o que é crucial para responder a problemas emergentes e melhorar a resiliência do sistema de energia.
#
#
# <h3>Pré-processamento dos dados no código fornecido:</h3>
#
# **Seleção de Colunas Relevantes:**
# No código, são especificadas as colunas necessárias para a análise através da lista columns_needed. Isso ajuda a reduzir a quantidade de dados a serem carregados e processados, tornando o processo mais eficiente.
#
# **Especificação dos Tipos de Dados:**
# O código especifica os tipos de dados adequados para cada coluna utilizando o parâmetro dtype ao ler o arquivo CSV. No entanto, todos os tipos de dados estão definidos como str, o que pode ser melhorado, especialmente para as colunas de datas.
#
# **Leitura do Arquivo CSV:**
# O arquivo CSV é lido utilizando a função pd.read_csv(). Durante a leitura, são aplicadas as configurações de encoding, separador, seleção de colunas e tipos de dados especificados.
#
# **Remoção de Valores em Branco:**
# O código remove todas as linhas com valores em branco na coluna 'NumOrdemInterrupcao' utilizando o método dropna(). Isso pode ser útil para garantir que apenas dados completos sejam utilizados na análise.
#
# **Agrupamento e Análise dos Dados:**
# Os dados são agrupados pela coluna 'NomAgenteRegulado' e é contado o número de valores distintos na coluna 'NumOrdemInterrupcao'. Essa análise fornece informações sobre a distribuição dos valores e permite identificar os agentes com o maior número de ocorrências.
#
# **Visualização dos Resultados:**
# Os resultados da análise são visualizados através de um gráfico de barras, onde são mostrados os cinco primeiros 'NomAgenteRegulado' com o maior número de 'NumOrdemInterrupcao'. Isso facilita a compreensão dos resultados e permite uma rápida identificação dos principais agentes.

# %% [markdown]
# <h2>Desenvolvimento</h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime


# Carregar o arquivo CSV
file_path = 'C:/Users/u11886/Desktop/MINERAÇÃO DE DADOS P1/interrupcoes-energia-eletrica-2024-datasetdefault.csv'
columns_needed = ['NumOrdemInterrupcao', 'NomAgenteRegulado', 'DscFatoGeradorInterrupcao', 'DatFimInterrupcao', 'DatInicioInterrupcao', 'DscSubestacaoDistribuicao', 'DscAlimentadorSubestacao', 'NumConsumidorConjunto', 'NumNivelTensao']
dtype = {'NumOrdemInterrupcao': str, 'NomAgenteRegulado': str, 'DscFatoGeradorInterrupcao': str, 'DatFimInterrupcao': str, 'DatInicioInterrupcao': str, 'DscSubestacaoDistribuicao': str, 'DscAlimentadorSubestacao': str, 'NumConsumidorConjunto': float, 'NumNivelTensao': float}
df_init = pd.read_csv(file_path, encoding='ISO-8859-1', sep=';', low_memory=False, usecols=columns_needed, dtype=dtype)

# Remove todas as linhas com valores em branco na coluna 'NumOrdemInterrupcao'
df = df_init.dropna(subset=['NumOrdemInterrupcao'])

# Agrupar os dados pela coluna 'NomAgenteRegulado' e contar os valores distintos na coluna 'NumOrdemInterrupcao'
grouped = df.groupby('NomAgenteRegulado')['NumOrdemInterrupcao'].nunique()

# Ordenar o DataFrame agrupado em ordem decrescente
grouped_sorted = grouped.sort_values(ascending=False)

# Pegar as 10 primeiras 'NomAgenteRegulado'
top_5 = grouped_sorted.head(10)

# Criar o gráfico
plt.figure(figsize=(10,6))
bars = top_5.plot(kind='bar')

plt.title('Top 10: Interrupções por distribuidora no Brasil no primeiro trimestre de 2024')
plt.xlabel('Distribuidora')
plt.ylabel('Contagem Distinta de Interrupções')

# Adicionar rótulos de dados
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.05, round(yval, 2), ha='center', va='bottom')

plt.show()

# %% [markdown]
# <h3>Comentários das colunas</h3>
#
# <p><b>1. NumOrdemInterrupcao:</b> Identificador da ocorrência.</p>
# <p><b>2.NomAgenteRegulado:</b> Nome do estado/distribuidora/empresa.</p>
# <p><b>3.DscFatoGeradorInterrupcao:</b> Fator gerador da interrupção.</p>
# <p><b>4.DatFimInterrupcao:</b> Data de fim da interrupção.</p>
# <p><b>5.DatInicioInterrupcao:</b> Data de início da interrupção.</p>
# <p><b>6.DscSubestacaoDistribuicao:</b> Código da subestação.</p>
# <p><b>7.DscAlimentadorSubestacao:</b> Código do alimentador.</p>
# <p><b>8.NumConsumidorConjunto:</b> Número de consumidores por conjunto.</p>
# <p><b>9.NumNivelTensao:</b> Número do Nível de tensão do equipamento interrompido.</p>

# %% [markdown]
# <h3>Comentários Gráfico 1</h3>
#
# As distribuidoras que mais possuem ocorrências no primeiro trimestre do ano de 2024 são CEMIG, COPEL, LIGHT, EQUATORIAL GOIÁS E AMPLA ENERGIA. A que lidera a posição negativa em relação ao cenário nacional é a CEMIG com 177.858 mil ocorrências no primeiro trimestre do ano vigente.

# %%
# Agrupar os dados pela coluna 'NomAgenteRegulado' e contar os valores distintos na coluna 'NumOrdemInterrupcao'
grouped = df.groupby('DscFatoGeradorInterrupcao')['NumOrdemInterrupcao'].nunique()

# Ordenar o DataFrame agrupado em ordem decrescente
grouped_sorted = grouped.sort_values(ascending=False)

# Pegar as 5 primeiras 'NomAgenteRegulado'
top_5 = grouped_sorted.head(5)

# Criar o gráfico
plt.figure(figsize=(10,6))
bars = top_5.plot(kind='bar')

plt.title('Top 5: Fator gerador de interrupções no Brasil no primeiro trimestre de 2024')
plt.xlabel('Fator gerador')
plt.ylabel('Contagem Distinta de interrupções')

# Adicionar rótulos de dados
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.05, round(yval, 2), ha='center', va='bottom')

plt.show()

# %% [markdown]
# <h3>Comentários Gráfico 2</h3>
#
# O fator gerador que mais impactou as ocorrências no primeiro trimestre foram por causas de falhas de materiais ou equipamentos e por causas climáticas de ventos, sendo assim, as ocorrências desse genêro tem natureza plausível de manutenção preventiva e corretiva.

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

df = df.copy()


df['DatFimInterrupcao'] = pd.to_datetime(df['DatFimInterrupcao'], format="%Y-%m-%d %H:%M:%S")
df['DatInicioInterrupcao'] = pd.to_datetime(df['DatInicioInterrupcao'], format="%Y-%m-%d %H:%M:%S")

# Calcula a diferença de tempo
df['DiferencaTempo'] = df['DatFimInterrupcao'] - df['DatInicioInterrupcao']

# Converte a diferença de tempo para horas
df['DiferencaTempo'] = df['DiferencaTempo'].dt.total_seconds()/3600

# Calcula o tempo médio para cada 'NumOrdemInterrupcao'
media_tempo = df.groupby('NumOrdemInterrupcao')['DiferencaTempo'].mean()

# Seleciona os três números de ordem de interrupção com as maiores médias de tempo de interrupção
top_5_numeros_ordem = media_tempo.nlargest(3)

# Cria uma figura e um eixo
fig, ax = plt.subplots()

# Plota os dados
top_5_numeros_ordem.plot(kind='line', ax=ax)

# Define os rótulos dos eixos
ax.set_xlabel('Interrupções')
ax.set_ylabel('Média do Tempo de Interrupção (horas)')

# Otimiza o espaçamento
plt.tight_layout()

# Mostra o gráfico
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h3>Comentários Gráfico 3</h3>
#
# O gráfico acima demonstra o tempo médio de interrupções em hora por ocorrência, o interesse nesse tipo de visão consiste em localizar as interrupções que mais afetaram no DEC e FEC por conta de sua elevada duração. A visão acima contempla o **tempo médio de interrupções para as 3 principais ocorrências, considerando todas as distribuidoras do Brasil**.

# %%
import matplotlib.pyplot as plt

# Agrupa por 'NomAgenteRegulado' e 'NumOrdemInterrupcao'
grupo = df.groupby(['NomAgenteRegulado', 'NumOrdemInterrupcao'])['DiferencaTempo'].mean()

# Obtém a lista de 'NomAgenteRegulado'
agentes = df['NomAgenteRegulado'].unique()

# Calcula a média do tempo de interrupção para cada agente
medias_por_agente = grupo.groupby('NomAgenteRegulado').mean()

# Seleciona os cinco agentes com as maiores médias
top_5_agentes = medias_por_agente.nlargest(5)

# Cria um gráfico para cada agente
for agente in top_5_agentes.index:
    if agente in grupo and not grupo[agente].isnull().all():
        # Cria uma figura e um eixo com tamanho maior
        fig, ax = plt.subplots(figsize=(10, 6))

        # Plota os dados para o agente atual
        grupo[agente].plot(kind='line', ax=ax)

        # Define os rótulos dos eixos
        ax.set_xlabel('Interrupções')
        ax.set_ylabel('Média do Tempo de Interrupção (horas)')

        # Define o título do gráfico
        ax.set_title(agente)

        # Rotaciona os rótulos do eixo X
        plt.xticks(rotation=45)

        # Otimiza o espaçamento
        plt.tight_layout()

        # Mostra o gráfico
        plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <h3>Comentários Gráficos 4,5,6,7 e 8</h3>
#
# A figura acima contempla o **as 5 principais distribuidoras com maior tempo médio de interrupções do Brasil**. Tendo o mesmo propósito da figura 3, porém expandindo as visões para cada distribuidora de energia, em que cada uma pode localizar as principais ocorrências do estado.

# %%
import matplotlib.pyplot as plt

# Extrai o mês da coluna 'DatInicioInterrupcao'
df['Mes'] = df['DatInicioInterrupcao'].dt.month

# Agrupa por 'NomAgenteRegulado' e 'Mes'
grupo = df.groupby(['NomAgenteRegulado', 'Mes'])['DiferencaTempo'].mean().nlargest(6)

# Obtém a lista de 'NomAgenteRegulado' que possuem pelo menos um mês com valor
agentes_com_dados = [agente for agente in df['NomAgenteRegulado'].unique() if agente in grupo and not grupo[agente].isnull().all()]

# Cria um gráfico para cada 'NomAgenteRegulado' que possui dados
for agente in agentes_com_dados:
    # Cria uma figura e um eixo
    fig, ax = plt.subplots()

    # Plota os dados para o 'NomAgenteRegulado' atual
    grupo[agente].plot(kind='bar', ax=ax)

    # Adiciona rótulos de dados a cada barra
    for i, v in enumerate(grupo[agente]):
        ax.text(i, v + 0.01, str(round(v, 2)), ha='center', va='bottom')

    # Define os rótulos dos eixos
    ax.set_xlabel('Mês')
    ax.set_ylabel('Média do Tempo de Interrupção (horas)')

    # Define o título do gráfico
    ax.set_title(agente)
    
    # Rotaciona os rótulos do eixo X
    plt.xticks(rotation=0)

    # Mostra o gráfico
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# <h3>Comentários Figura 9,10,11,12 e 13</h3>
#
# A figura acima contempla o **as 5 principais distribuidoras que tiveram maior tempo médio de interrupções**. Tendo o mesmo propósito da figura 4, porém expandindo as visões para cada mês do primeiro trimestre do ano de 2024.

# %%
# Copie o DataFrame original
df = df.copy()

# Concatene as colunas DscSubestacaoDistribuicao e DscAlimentadorSubestacao para criar a coluna SEAL
df['SEAL'] = df['DscSubestacaoDistribuicao'] + df['DscAlimentadorSubestacao']

# Filtrar o DataFrame original para remover o outlier no eixo X
df_filtered = df[df['SEAL'] != '--']

# Contagem distinta de NumOrdemInterrupcao por SEAL
grouped = df_filtered.groupby('SEAL')['NumOrdemInterrupcao'].nunique()

# Ordenar os SEALs pela contagem distinta em ordem decrescente
grouped_sorted = grouped.sort_values(ascending=False)

# Selecionar apenas os 20 primeiros SEALs
top_10_seals = grouped_sorted.head(20)

# Criar o gráfico
plt.figure(figsize=(10, 6))
bars = top_10_seals.plot(kind='bar')

plt.title('Top 20 circuitos com Maior Contagem Distinta de Interrupções (sem o outlier "--")')
plt.xlabel('Circuitos')
plt.ylabel('Contagem Distinta de Interrupções')

# Adicionar rótulos de dados
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.05, round(yval, 2), ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <h3>Comentários Gráfico 14</h3>
#
# A figura acima contempla os principais circuitos(alimentadores) que mais interroperam na rede elétrica em 2024, considerando os circuitos de todas as distribuidoras.

# %%
# Remove todas as linhas com valores em branco nas colunas 'NumOrdemInterrupcao' e 'NumConsumidorConjunto'
df = df_init.dropna(subset=['NumOrdemInterrupcao', 'NumConsumidorConjunto'])

# Agrupar os dados pela coluna 'NomAgenteRegulado' e calcular a média de 'NumConsumidorConjunto'
grouped = df.groupby('NomAgenteRegulado')['NumConsumidorConjunto'].mean()

# Ordenar o DataFrame agrupado em ordem decrescente
grouped_sorted = grouped.sort_values(ascending=False)

# Pegar as 10 primeiras 'NomAgenteRegulado'
top_10 = grouped_sorted.head(10)

# Criar o gráfico
plt.figure(figsize=(10, 6))
bars = top_10.plot(kind='barh')

plt.title('Top 10: Distribuidoras com Maior Média de Consumidores Conjuntos no Brasil no Primeiro Trimestre de 2024')
plt.xlabel('Média de Consumidores Conjuntos')
plt.ylabel('Distribuidora')

# Adicionar rótulos de dados sem casas decimais
for bar in bars.patches:
    xval = int(bar.get_width())
    plt.text(xval + 0.05, bar.get_y() + bar.get_height()/2, xval, ha='left', va='center')
    
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <h3>Comentários Gráfico 15</h3>
#
# A análise das distribuidoras de energia com a maior média de consumidores conjuntos no Brasil no primeiro trimestre de 2024 é essencial para compreender a dinâmica e a demanda energética do país. Essa análise oferece insights valiosos sobre a eficiência operacional das distribuidoras, a densidade populacional das áreas atendidas e as necessidades de infraestrutura energética em diferentes regiões. Além disso, permite identificar líderes de mercado e oportunidades de investimento, auxiliando no planejamento estratégico do setor elétrico e na alocação eficiente de recursos.

# %%
# Remove todas as linhas com valores em branco nas colunas necessárias
df = df_init.dropna(subset=['NumOrdemInterrupcao', 'NumNivelTensao'])

def plot_top_10_by_tension(df, tension_level):
    # Filtrar o DataFrame para o nível de tensão especificado
    df_filtered = df[df['NumNivelTensao'] == tension_level]

    # Agrupar os dados pela coluna 'NomAgenteRegulado' e contar os valores distintos na coluna 'NumOrdemInterrupcao'
    grouped = df_filtered.groupby('NomAgenteRegulado')['NumOrdemInterrupcao'].nunique()

    # Ordenar o DataFrame agrupado em ordem decrescente
    grouped_sorted = grouped.sort_values(ascending=False)

    # Pegar as 10 primeiras 'NomAgenteRegulado'
    top_10 = grouped_sorted.head(10)

    # Criar o gráfico
    plt.figure(figsize=(10, 6))
    bars = top_10.plot(kind='barh')

    plt.title(f'Top 10: Distribuidoras com Mais Interrupções com Nível de Tensão {tension_level}V no Brasil no Primeiro Trimestre de 2024')
    plt.xlabel('Contagem Distinta de Interrupções')
    plt.ylabel('Distribuidora')

    # Adicionar rótulos de dados sem casas decimais
    for bar in bars.patches:
        xval = int(bar.get_width())
        plt.text(xval + 0.05, bar.get_y() + bar.get_height()/2, xval, ha='left', va='center')
    plt.tight_layout()
    plt.show()

# Gerar gráfico para nível de tensão 13800
plot_top_10_by_tension(df, 13800)

# Gerar gráfico para nível de tensão 34500
plot_top_10_by_tension(df, 34500)

# Gerar gráfico para nível de tensão 69000
plot_top_10_by_tension(df, 69000)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# <h3>Comentários Gráficos 16, 17 e 18</h3>
#
# A análise das distribuidoras de energia com o maior número de interrupções em um determinado nível de tensão no Brasil durante o primeiro trimestre de 2024 é de suma importância para compreender os desafios e as tendências do setor elétrico. Essa abordagem fornece insights cruciais sobre a confiabilidade e a resiliência das redes elétricas em diferentes regiões, destacando as áreas que podem enfrentar problemas de fornecimento de energia e demandando uma atenção prioritária para melhorias na infraestrutura.

# %% [markdown]
# <h2>Resultados e discussões</h2>
#
# **Análise dos Dados Pós-Pré-processamento:**
# Após o pré-processamento dos dados da base "Interrupções de Energia Elétrica nas Redes de Distribuição", os dados foram transformados e otimizados para análise posterior. Foram removidas linhas com valores em branco na coluna 'NumOrdemInterrupcao', garantindo que apenas dados completos fossem considerados. Além disso, as colunas relevantes foram selecionadas, incluindo 'NumOrdemInterrupcao', 'NomAgenteRegulado', 'DscFatoGeradorInterrupcao', 'DatFimInterrupcao' e 'DatInicioInterrupcao'.
#
# A análise pós-pré-processamento incluiu a contagem de valores distintos de 'NumOrdemInterrupcao' para cada 'NomAgenteRegulado', revelando os principais agentes com o maior número de interrupções. Esses resultados foram visualizados em um gráfico de barras mostrando as cinco primeiras 'NomAgenteRegulado' com o maior número de interrupções, facilitando a identificação visual dos agentes mais impactados.
#
# **Impacto das Técnicas Utilizadas:**
# As técnicas de pré-processamento utilizadas tiveram um impacto significativo na qualidade dos dados e na eficiência subsequente da mineração de dados. A remoção de valores em branco e a seleção de colunas relevantes garantiram que apenas dados completos e importantes fossem considerados na análise. Isso reduziu a possibilidade de introdução de erros e permitiu uma análise mais precisa e confiável dos dados.
#
# Além disso, a visualização dos resultados permitiu uma compreensão mais clara dos padrões nos dados e facilitou a identificação dos principais agentes afetados por interrupções de energia elétrica. Isso pode informar decisões estratégicas para melhorar a confiabilidade e a eficiência do sistema de distribuição de energia elétrica, mostrando o impacto prático das técnicas de pré-processamento na tomada de decisões no setor elétrico.
#
# No entanto, ainda há espaço para melhorias, como a conversão adequada das datas para objetos de data e a exploração de técnicas mais avançadas de tratamento de valores ausentes e normalização de dados. Estas melhorias podem contribuir ainda mais para a qualidade e eficácia da análise de dados nesta base específica.

# %% [markdown]
# <h2>Conclusão</h2>
#
# O processo de pré-processamento de dados desempenha um papel fundamental em projetos de mineração de dados, como demonstrado pela abordagem prática aplicada à base de dados "Interrupções de Energia Elétrica nas Redes de Distribuição". Durante esta análise, alguns aprendizados importantes foram destacados, assim como áreas potenciais para melhorias e possíveis aplicações futuras.
#
# **Sumário dos Aprendizados:**
# Durante o pré-processamento dos dados, aprendemos a importância da seleção cuidadosa de colunas relevantes para análise, a necessidade de lidar com valores ausentes de forma eficaz e a utilidade de técnicas como agrupamento e visualização para entender melhor os padrões nos dados. Além disso, reconhecemos a importância de especificar corretamente os tipos de dados, especialmente para datas, a fim de evitar erros e garantir uma análise precisa.
#
# **Possíveis Melhorias:**
# Existem várias melhorias que podem ser exploradas em trabalhos futuros. Uma delas é aprimorar a especificação dos tipos de dados, especialmente para as colunas de datas, utilizando métodos adequados de conversão de tipos. Além disso, a aplicação de técnicas mais avançadas de tratamento de valores ausentes e de normalização de dados pode contribuir para uma análise mais precisa e robusta. Também seria interessante explorar métodos de engenharia de recursos para criar novas características derivadas que possam melhorar a eficácia dos modelos de mineração de dados.
#
# **Aplicações Futuras:**
# Os dados preparados podem ser utilizados em uma variedade de projetos futuros de mineração de dados. Por exemplo, eles podem ser utilizados para desenvolver modelos preditivos que prevejam interrupções futuras na rede de distribuição de energia elétrica com base em padrões históricos. Além disso, os dados podem ser explorados para identificar tendências e padrões de ocorrência de interrupções, o que pode informar decisões estratégicas para melhorar a confiabilidade e a eficiência do sistema de distribuição de energia elétrica.
#
# Em resumo, o pré-processamento de dados é uma etapa essencial em projetos de mineração de dados, e sua aplicação eficaz pode levar a insights valiosos e a tomadas de decisão informadas em uma variedade de contextos, incluindo o setor de energia elétrica.
#
# <h2>Referências</h2>
#
# Reichert Junior, I. (2023)Pré-Processamento de Dados: O que é? Por que fazer?. Este artigo discute a importância do pré-processamento de dados e as técnicas envolvidas, como limpeza de dados, transformação de dados e redução de dados.
#
# <https://medium.com/@ingoreichertjr/pr%C3%A9-processamento-de-dados-o-que-%C3%A9-por-que-fazer-dfc9fa3df8a3>
#
# Soares, J. A. (n.d.)Pré-Processamento em Mineração de Dados: Um Estudo Comparativo em Complementação. Este trabalho analisa os efeitos da aplicação de tarefas de seleção e agrupamento antes da imputação de valores ausentes em conjuntos de dados.
#
# <https://www.academia.edu/37080506/Pr%C3%A9_Processamento_em_Minera%C3%A7%C3%A3o_de_Dados_Um_Estudo_Comparativo_em_Complementa%C3%A7%C3%A3o>
#
# Mineração de Dados e Pré-Processamento de Dados – PPCIC. Este recurso discute o pré-processamento de dados como um passo importante no processo de extração de conhecimento a partir de dados.
#
# <https://eic.cefet-rj.br/ppcic/index.php/mineracao-dados/>
#
# Mineração de Dados: o que é, como funciona e cases reais. Este artigo discute o processo de mineração de dados, incluindo a etapa de pré-processamento.
#
# <https://www.mjvinnovation.com/pt-br/blog/mineracao-de-dados-cases/>
